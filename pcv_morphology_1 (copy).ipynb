# %%
# !pip install plantcv
# Import libraries
from plantcv import plantcv as pcv
# Out:
# Requirement already satisfied: plantcv in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (3.14.2)
# Requirement already satisfied: opencv-python in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plantcv) (4.7.0.68)
# Requirement already satisfied: scipy in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plantcv) (1.9.3)
# Requirement already satisfied: scikit-image>=0.13 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plantcv) (0.19.2)
# Requirement already satisfied: matplotlib<3.6,>=1.5 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plantcv) (3.5.2)
# Requirement already satisfied: dask in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plantcv) (2022.7.0)
# Requirement already satisfied: dask-jobqueue in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plantcv) (0.8.1)
# Requirement already satisfied: pandas in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plantcv) (1.4.4)
# Requirement already satisfied: numpy<1.23,>=1.11 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plantcv) (1.22.4)
# Requirement already satisfied: scikit-learn in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plantcv) (1.0.2)
# Requirement already satisfied: statsmodels in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plantcv) (0.13.2)
# Requirement already satisfied: python-dateutil in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plantcv) (2.8.2)
# Requirement already satisfied: plotnine in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plantcv) (0.10.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from matplotlib<3.6,>=1.5->plantcv) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from matplotlib<3.6,>=1.5->plantcv) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from matplotlib<3.6,>=1.5->plantcv) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from matplotlib<3.6,>=1.5->plantcv) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from matplotlib<3.6,>=1.5->plantcv) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from matplotlib<3.6,>=1.5->plantcv) (0.11.0)
# Requirement already satisfied: six>=1.5 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from python-dateutil->plantcv) (1.16.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from scikit-image>=0.13->plantcv) (2021.7.2)
# Requirement already satisfied: networkx>=2.2 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from scikit-image>=0.13->plantcv) (2.8.4)
# Requirement already satisfied: PyWavelets>=1.1.1 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from scikit-image>=0.13->plantcv) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from scikit-image>=0.13->plantcv) (2.19.3)
# Requirement already satisfied: toolz>=0.8.2 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from dask->plantcv) (0.11.2)
# Requirement already satisfied: cloudpickle>=1.1.1 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from dask->plantcv) (2.0.0)
# Requirement already satisfied: partd>=0.3.10 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from dask->plantcv) (1.2.0)
# Requirement already satisfied: fsspec>=0.6.0 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from dask->plantcv) (2022.7.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from dask->plantcv) (6.0)
# Requirement already satisfied: distributed>=2022.02.0 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from dask-jobqueue->plantcv) (2022.7.0)
# Requirement already satisfied: pytz>=2020.1 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from pandas->plantcv) (2022.1)
# Requirement already satisfied: patsy>=0.5.1 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plotnine->plantcv) (0.5.2)
# Requirement already satisfied: mizani>=0.8.1 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from plotnine->plantcv) (0.8.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from scikit-learn->plantcv) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from scikit-learn->plantcv) (1.1.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (1.7.0)
# Requirement already satisfied: psutil>=5.0 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (5.9.0)
# Requirement already satisfied: jinja2 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (2.11.3)
# Requirement already satisfied: locket>=1.0.0 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (1.0.0)
# Requirement already satisfied: click>=6.6 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (8.0.4)
# Requirement already satisfied: msgpack>=0.6.0 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (1.0.3)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (2.4.0)
# Requirement already satisfied: zict>=0.1.3 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (2.1.0)
# Requirement already satisfied: tornado<6.2,>=6.0.3 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (6.1)
# Requirement already satisfied: urllib3 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from distributed>=2022.02.0->dask-jobqueue->plantcv) (1.26.14)
# Requirement already satisfied: palettable in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from mizani>=0.8.1->plotnine->plantcv) (3.3.0)
# Requirement already satisfied: heapdict in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from zict>=0.1.3->distributed>=2022.02.0->dask-jobqueue->plantcv) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (from jinja2->distributed>=2022.02.0->dask-jobqueue->plantcv) (2.0.1)

# %%
# !pip install --upgrade pip
# Set the notebook display method
# inline = embedded plots, notebook = interactive plots
# %matplotlib inline
# Out:
# Requirement already satisfied: pip in /home/grads/y/yashzambre/anaconda3/lib/python3.9/site-packages (23.0)

# %%
class options:
    def __init__(self):
        self.image = "/home/grads/y/yashzambre/Desktop/YASH/pcv.png"
        self.debug = "plot"
        self.writeimg= False
        self.result = "vis_tutorial_results.json"
        self.outdir = "." # Store the output to the current directory
        
# Get options
args = options()

# Set debug to the global parameter 
pcv.params.debug = args.debug

# %%
# Get options
args = options()

# Set debug to the global parameter
pcv.params.debug = args.debug

# Set plotting size (default = 100)
pcv.params.dpi = 100

# Increase text size and thickness to make labels clearer
# (size may need to be altered based on original image size)
pcv.params.text_size = 2
pcv.params.text_thickness = 2
pcv.params.line_thickness = 10

# %%
# Inputs:
#   filename - Image file to be read in 
#   mode - How to read in the image; either 'native' (default), 'rgb', 'gray', or 'csv'
img, path, filename = pcv.readimage(filename=args.image)

# %%
# Inputs:
#   rbg_img      = original image
#   original_img = whether to include the original RGB images in the display: True (default) or False
colorspaces = pcv.visualize.colorspaces(rgb_img=img)

# %%
s = pcv.rgb2gray_hsv(rgb_img=img, channel='s')

# %%
# Take a binary threshold to separate plant from background. 
# Threshold can be on either light or dark objects in the image. 

# Inputs:
#   gray_img - Grayscale image data 
#   threshold- Threshold value (between 0-255)
#   max_value - Value to apply above threshold (255 = white) 
#   object_type - 'light' (default) or 'dark'. If the object is lighter than 
#                 the background then standard threshold is done. If the object 
#                 is darker than the background then inverse thresholding is done. 
s_thresh = pcv.threshold.binary(gray_img=s, threshold=85, max_value=255, object_type='light')

# %%
skeleton = pcv.morphology.skeletonize(s_thresh)

# %%
# Prune the skeleton  
# Generally, skeletonized images will have barbs (this image is particularly ideal, 
# that's why it's the example image in the tutorial!), 
# representing the width, that need to get pruned off. 

# Inputs:
#   skel_img = Skeletonized image
#   size     = Size to get pruned off each branch
#   mask     = (Optional) binary mask for debugging. If provided, debug image will be overlaid on the mask.
img1, seg_img, edge_objects = pcv.morphology.prune(skel_img=skeleton, size=1)

# %%
# Fill in segments (also stores out area data)  

# Inputs:
# mask         = Binary image, single channel, object = 1 and background = 0
# objects      = List of contours
# label        = Optional label parameter, modifies the variable name of observations recorded. (default `label="default"`)filled_img = pcv.morphology.fill_segments(mask=cropped_mask, objects=edge_objects)

filled_img = pcv.morphology.fill_segments(mask=s_thresh, objects=edge_objects, label="default")

# %%
# Identify branch points   

# Inputs:
#   skel_img = Skeletonized image
#   mask     = (Optional) binary mask for debugging. If provided, debug image will be overlaid on the mask.
#   label    = Optional label parameter, modifies the variable name of observations recorded. (default `label="default"`)filled_img = pcv.morphology.fill_segments(mask=cropped_mask, objects=edge_objects)

branch_pts_mask = pcv.morphology.find_branch_pts(skel_img=skeleton, mask=s_thresh)

# %%
# Identify tip points   

# Inputs:
#   skel_img = Skeletonized image
#   mask     = (Optional) binary mask for debugging. If provided, debug 
#              image will be overlaid on the mask
#   label    = Optional label parameter, modifies the variable name of observations recorded. (def
# ault `label="default"`)filled_img = pcv.morphology.fill_segments(mask=cropped_mask, objects=edge_objects)

tip_pts_mask = pcv.morphology.find_tips(skel_img=skeleton, mask=None, label="default")

# %%
leaf_obj, stem_obj = pcv.morphology.segment_sort(skel_img=skeleton, 
                                                 objects=edge_objects,
                                                 mask=s_thresh)

# %%
segmented_img, labeled_img = pcv.morphology.segment_id(skel_img=skeleton,
                                                       objects=leaf_obj,
                                                       mask=s_thresh)

# %%
pcv.params.text_size=.3 # (default text_size=.55)
pcv.params.text_thickness=1 # (defaul text_thickness=2) 

segmented_img, labeled_img = pcv.morphology.segment_id(skel_img=skeleton,
                                                       objects=leaf_obj,
                                                       mask=s_thresh)

# %%
labeled_img  = pcv.morphology.segment_path_length(segmented_img=segmented_img, 
                                                  objects=leaf_obj, label="default")

# %%
labeled_img = pcv.morphology.segment_euclidean_length(segmented_img=segmented_img,
                                                        objects=leaf_obj, label="default")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_25832/1774633008.py in <module>
# ----> 1 labeled_img = pcv.morphology.segment_euclidean_length(segmented_img=segmented_img,
#       2                                                         objects=leaf_obj, label="default")
#       3
#
# ~/anaconda3/lib/python3.9/site-packages/plantcv/plantcv/morphology/segment_euclidean_length.py in segment_euclidean_length(segmented_img, objects, label)
#      53         points = []
#      54         if not len(tip_objects) == 2:
# ---> 55             fatal_error("Too many tips found per segment, try pruning again")
#      56         for t in tip_objects:
#      57             # Gather pairs of coordinates
#
# ~/anaconda3/lib/python3.9/site-packages/plantcv/plantcv/fatal_error.py in fatal_error(error)
#      11     :return:
#      12     """
# ---> 13     raise RuntimeError(error)
#
# RuntimeError: Too many tips found per segment, try pruning again

# %%
labeled_img = pcv.morphology.segment_euclidean_length(segmented_img=segmented_img, 
                                                      objects=leaf_obj, label="default")
